# %%
import matplotlib.pyplot as plt
import cv2

# %%
labels_list = [{'label': 'down', 'x1': 308, 'y1': 375, 'x2': 357, 'y2': 418},
 {'label': 5, 'x1': 362, 'y1': 378, 'x2': 442, 'y2': 454}]

# %%
labels_list
# Out:
# [{'label': 'down', 'x1': 308, 'y1': 375, 'x2': 357, 'y2': 418},
#  {'label': 5, 'x1': 362, 'y1': 378, 'x2': 442, 'y2': 454}]

# %%
input_img = cv2.imread('./images/osmo13.jpg')
img = cv2.resize(input_img, (640, 640))

# %%
i = 1
crop_img = img[int(labels_list[i]['y1']):int(labels_list[i]['y2']),
               int(labels_list[i]['x1']):int(labels_list[i]['x2'])]

# %%
plt.imshow(crop_img)

# %%
cv2.imwrite('./images/train/two3.jpg', crop_img)
# Out:
# True

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

import random

from keras.models import load_model

import warnings
warnings.filterwarnings(action='ignore')

# %%
image_path = './images/osmo12.jpg'

# %%
input_img = cv2.imread(image_path)
img = cv2.resize(input_img, (640, 640))

# %%
plt.imshow(img)
